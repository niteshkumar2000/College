# %% [markdown]
# # Assignment 1

# %% [markdown]
# ##  Import Modules

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Reading Input Data

# %%
data = pd.read_csv('Data set 1.csv')
data.head(5)
# Out:
#   shelf                       name mfr type  ...  potass  vitamins  weight  cups
# 0   Top                  100%_Bran   N    C  ...   280.0        25     1.0  0.33
# 1   Top          100%_Natural_Bran   Q    C  ...   135.0         0     1.0  1.00
# 2   Top                   All-Bran   K    C  ...   320.0        25     1.0  0.33
# 3   Top  All-Bran_with_Extra_Fiber   K    C  ...   330.0        25     1.0  0.50
# 4   Top             Almond_Delight   R    C  ...     NaN        25     1.0  0.75
#
# [5 rows x 15 columns]

# %% [markdown]
# ### Question - 1 <br>
# Quantitative variables -  Variables whose values result from counting or measuring something. <br>
# Qualitative variables - Variables that are not measurement variables. Their values do not result from measuring or counting. <br>
#
# From the given dataset,
# - Quantitative variables
#     - calories
#     - protein
#     - fat
#     - carbo
#     - sugars
#     - potass
#     - vitamins
#     - weight
#     - cups
# - Qualitative variables
#     - shelf
#     - mfr
#     - type

# %% [markdown]
# ### Question - 2
#
# Histogram of association between shelf position and sugar content of the variables from the shelf

# %%
# data['shelf'].unique()
top_shelf = data[(data['shelf'] == 'Top')]
middle_shelf = data[(data['shelf'] == 'Middle')]
bottom_shelf = data[(data['shelf'] == 'Bottom')]

fig, axs = plt.subplots(1, 3)

axs[0].hist(top_shelf['sugars'])
axs[0].set_title('Top Shelf Sugar')

axs[1].hist(middle_shelf['sugars'])
axs[1].set_title('Middle Shelf Sugar')

axs[2].hist(bottom_shelf['sugars'])
axs[2].set_title('Bottom Shelf Sugar')

top_shelf['sugars'].mean(), middle_shelf['sugars'].mean(), bottom_shelf['sugars'].mean()
# Out:
# (6.527777777777778, 9.619047619047619, 5.105263157894737)

# %% [markdown]
# ### Question - 3
#
# From the histogram it looks like middle shelf has most sugar content followed by top and bottom. Hence the order is
# - middle
# - top
# - bottom

# %% [markdown]
# ### Question - 4
# Five-number-summary plot for the variable 'fiber'

# %%
# Thanks to pandas, describe function gives it very easily xD
plt.boxplot(data['fiber'])
data['fiber'].describe()
# Out:
# count    77.000000
# mean      2.151948
# std       2.383364
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max      14.000000
# Name: fiber, dtype: float64

# %% [markdown]
# ### Question - 5
#
# Scatter plot between calories and carbohydrates

# %%
plt.scatter(data['calories'], data['carbo'])
plt.title('Scatter Plot - Calories vs Carbohydrates')
plt.xlabel('Calories')
plt.ylabel('Carbohydrates')
# Out:
# Text(0, 0.5, 'Carbohydrates')

# %% [markdown]
# From the plot, we dont see any such linear increase (positive association) or linear decrease (negative association) between the variables. <br>
# Hence, we can conclude that these two variables has no linear association.
